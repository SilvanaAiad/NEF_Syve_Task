# %% [markdown]
# ### Reading Given Data

# %%
#Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#ٌReading the data

kubectl_top_data = pd.read_table("/NEF_Syve_Task/input1.txt", delimiter=r"\s+")

# %% [markdown]
# #Checking the Data

# %%
#checking the data

kubectl_top_data.head()
# Out:
#      NAME_OF_POD  CPU  MEM
# 0  kubectl-pod-1   10   11
# 1  kubectl-pod-2   23   11
# 2  kubectl-pod-3   42   11
# 3  kubectl-pod-4   33   11
# 4  kubectl-pod-5   29   11

# %%
#knowing the total number of rows and columns

kubectl_top_data.shape
# Out:
# (30, 3)

# %%
#checking if there any NULL Cell 

kubectl_top_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NAME_OF_POD  30 non-null     object
#  1   CPU          30 non-null     int64
#  2   MEM          30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes

# %% [markdown]
# ### Task 1

# %%
#grouping the data by pod type and knowing biggest CPU and Memory value for each of the pods
#getting maximum values
POD_Comparison = kubectl_top_data.groupby('NAME_OF_POD')[['CPU','MEM']].max()
POD_Comparison = POD_Comparison.reset_index()
POD_Comparison
# Out:
#      NAME_OF_POD  CPU  MEM
# 0  kubectl-pod-1   39   11
# 1  kubectl-pod-2   68   66
# 2  kubectl-pod-3   42   11
# 3  kubectl-pod-4   71   15
# 4  kubectl-pod-5   29   73

# %%
#Rename the columns

POD_Comparison.columns = ["NAME_OF_POD" , "MAX_CPU" , "MAX_MEM" ]
POD_Comparison
# Out:
#      NAME_OF_POD  MAX_CPU  MAX_MEM
# 0  kubectl-pod-1       39       11
# 1  kubectl-pod-2       68       66
# 2  kubectl-pod-3       42       11
# 3  kubectl-pod-4       71       15
# 4  kubectl-pod-5       29       73

# %%
# creating new file for the new result 

result1 = POD_Comparison.to_csv('/NEF_Syve_Task/result1.txt', sep = "\t" , index = False, mode = 'w')

# %% [markdown]
# ### Task 2

# %%
#Open input2 file 
Boundary_Values = pd.read_table("/NEF_Syve_Task/input2.txt", delimiter=r"\s+", header= None)

#Rename the columns
Boundary_Values.columns = ['NAME_OF_POD' , 'ACC_CPU' , 'ACC_MEM']
Boundary_Values
# Out:
#      NAME_OF_POD  ACC_CPU  ACC_MEM
# 0  kubectl-pod-1       50       11
# 1  kubectl-pod-2       67       66
# 2  kubectl-pod-3       10       10
# 3  kubectl-pod-4       70       14
# 4  kubectl-pod-5       28        1

# %%
#result1 table 
POD_Comparison
# Out:
#      NAME_OF_POD  MAX_CPU  MAX_MEM
# 0  kubectl-pod-1       39       11
# 1  kubectl-pod-2       68       66
# 2  kubectl-pod-3       42       11
# 3  kubectl-pod-4       71       15
# 4  kubectl-pod-5       29       73

# %%
#Collecting all data in one table
Below_OR_Beyond = POD_Comparison.copy()
Below_OR_Beyond['ACC_CPU'] = Boundary_Values['ACC_CPU']
Below_OR_Beyond['ACC_MEM'] = Boundary_Values['ACC_MEM']
Below_OR_Beyond
# Out:
#      NAME_OF_POD  MAX_CPU  MAX_MEM  ACC_CPU  ACC_MEM
# 0  kubectl-pod-1       39       11       50       11
# 1  kubectl-pod-2       68       66       67       66
# 2  kubectl-pod-3       42       11       10       10
# 3  kubectl-pod-4       71       15       70       14
# 4  kubectl-pod-5       29       73       28        1

# %%
#Is it below or beyond the acceptable value
Below_OR_Beyond ['Compare_CPU'] = np.where(Below_OR_Beyond['MAX_CPU'] <= Below_OR_Beyond['ACC_CPU'] , True, False)
Below_OR_Beyond ['Compare_MEM'] = np.where(Below_OR_Beyond['MAX_MEM'] <= Below_OR_Beyond['ACC_MEM'] , True, False)
Below_OR_Beyond
# Out:
#      NAME_OF_POD  MAX_CPU  MAX_MEM  ACC_CPU  ACC_MEM  Compare_CPU  Compare_MEM
# 0  kubectl-pod-1       39       11       50       11         True         True
# 1  kubectl-pod-2       68       66       67       66        False         True
# 2  kubectl-pod-3       42       11       10       10        False        False
# 3  kubectl-pod-4       71       15       70       14        False        False
# 4  kubectl-pod-5       29       73       28        1        False        False

# %%
#Two list of pods that performed below their boundaries in terms of CPU and Memory.
#CPU
CPU_Below = Below_OR_Beyond.loc[Below_OR_Beyond['Compare_CPU'] == True , ['NAME_OF_POD']]
POD_CPU_Below = CPU_Below ['NAME_OF_POD'].tolist()

#MEMORY
MEM_Below = Below_OR_Beyond.loc[Below_OR_Beyond['Compare_MEM'] == True , ['NAME_OF_POD']]
POD_MEM_Below = MEM_Below['NAME_OF_POD'].tolist()

# %%
#Two list of pods that went beyond their acceptable limits in terms of CPU and Memory.
#CPU
CPU_Beyond = Below_OR_Beyond.loc[Below_OR_Beyond['Compare_CPU'] == False , ['NAME_OF_POD']]
POD_CPU_Beyond = CPU_Beyond['NAME_OF_POD'].tolist()

#MEMORY
MEM_Beyond = Below_OR_Beyond.loc[Below_OR_Beyond['Compare_MEM'] == False , ['NAME_OF_POD']]
POD_MEM_Beyond = MEM_Beyond ['NAME_OF_POD'].tolist()

# %%
#open result2 file
result2 = open('/NEF_Syve_Task/result2.txt',  mode = 'w')
result2.write("List of pods NOT Exceeded CPU limit: ")
for item in POD_CPU_Below:
  result2.write("\n\t%s" % item)
result2.write("\nList of pods NOT Exceeded MRM limit: ")
for item in POD_MEM_Below:
  result2.write("\n\t%s" % item)
result2.write("\nList of pods Exceeded CPU limit: ")
for item in POD_CPU_Beyond:
  result2.write("\n\t%s" % item)
result2.write("\nList of pods Exceeded MEM limit: ")
for item in POD_MEM_Beyond:
  result2.write("\n\t%s" % item)
result2.close()

# %% [markdown]
# ### Task 3: Data Visulization

# %%
sorted_data = kubectl_top_data.sort_values('NAME_OF_POD', ignore_index = True)
sorted_data
# Out:
#       NAME_OF_POD  CPU  MEM
# 0   kubectl-pod-1   10   11
# 1   kubectl-pod-1    9   11
# 2   kubectl-pod-1   11   11
# 3   kubectl-pod-1   23   11
# 4   kubectl-pod-1   26   11
# 5   kubectl-pod-1   39   11
# 6   kubectl-pod-2   32   55
# 7   kubectl-pod-2   32   44
# 8   kubectl-pod-2   68   66
# 9   kubectl-pod-2   45   33
# 10  kubectl-pod-2   67   22
# 11  kubectl-pod-2   23   11
# 12  kubectl-pod-3    3    1
# 13  kubectl-pod-3    6    1
# 14  kubectl-pod-3    3    1
# 15  kubectl-pod-3    1    1
# 16  kubectl-pod-3    3    1
# 17  kubectl-pod-3   42   11
# 18  kubectl-pod-4   70   13
# 19  kubectl-pod-4   70   14
# 20  kubectl-pod-4   70   14
# 21  kubectl-pod-4   33   11
# 22  kubectl-pod-4   71   12
# 23  kubectl-pod-4   70   15
# 24  kubectl-pod-5   29   67
# 25  kubectl-pod-5   29   73
# 26  kubectl-pod-5   29   45
# 27  kubectl-pod-5   29   11
# 28  kubectl-pod-5   29   70
# 29  kubectl-pod-5   29    1

# %%
sorted_data.groupby('NAME_OF_POD').plot(kind = 'bar' , legend = True , subplots = True )
# Out:
# NAME_OF_POD
# kubectl-pod-1    [AxesSubplot(0.125,0.536818;0.775x0.343182), A...
# kubectl-pod-2    [AxesSubplot(0.125,0.536818;0.775x0.343182), A...
# kubectl-pod-3    [AxesSubplot(0.125,0.536818;0.775x0.343182), A...
# kubectl-pod-4    [AxesSubplot(0.125,0.536818;0.775x0.343182), A...
# kubectl-pod-5    [AxesSubplot(0.125,0.536818;0.775x0.343182), A...
# dtype: object
